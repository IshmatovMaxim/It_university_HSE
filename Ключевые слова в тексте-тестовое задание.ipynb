# %%
from rutermextract import TermExtractor

# %%
term_extractor = TermExtractor()
file = open('text_input.txt', 'r') # На вход подается сказака о рыбаке и рыбке
text = file.read()

word = [] # Пустой список для ключевых слов
value = [] # Пустой список для количества повторений


'''
В цикле term_extractor извлекает ключевые фразы из TXT-файла,
аргумент nested=True дополнительно извлекает ключевые слова из словосочетаний
'''


for term in term_extractor(text, nested=True):
    word.append(term.normalized) # Добавляет в список слова в нормализованной форме
    value.append(term.count) # Добавляет в список количество вхождений
    #print(term.normalized, term.count)
# Out:
# /home/computer/anaconda3/lib/python3.6/re.py:212: FutureWarning: split() requires a non-empty pattern match.
#   return _compile(pattern, flags).split(string, maxsplit)

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Word': word,
    'Value': value
})

# %%
df
# Out:
#                    Word  Value
# 0                 рыбка     34
# 1               старуха     27
# 2                старик     23
# 3         золотая рыбка     12
# 4                   мор     11
# 5                  море      8
# 6                царица      7
# 7                 невод      7
# 8                корыто      7
# 9                старча      6
# 10                 пуща      6
# 11             дворянка      6
# 12           синий море      5
# 13            синее мор      5
# 14               поклон      5
# 15                 изба      5
# 16             дурачина      5
# 17           государыня      5
# 18                  бог      5
# 19           простофиля      4
# 20             землянка      4
# 21   столбовая дворянка      3
# 22       вольная царица      3
# 23                  раз      3
# 24                новое      3
# 25                  муж      3
# 26                 баба      3
# 27         тридцать лет      2
# 28             три года      2
# 29        твоя душенька      2
# ..                  ...    ...
# 111              палата      1
# 112                 очи      1
# 113               ответ      1
# 114          осердилася      1
# 115              окошко      1
# 116                ноги      1
# 117                нога      1
# 118               наука      1
# 119            народ-то      1
# 120               мужик      1
# 121             маковка      1
# 122             крыльцо      1
# 123             корысть      1
# 124             конюшня      1
# 125               кичка      1
# 126             золотые      1
# 127             жемчуги      1
# 128          душегрейка      1
# 129              дорога      1
# 130            двери-то      1
# 131               голос      1
# 132              вороты      1
# 133               волна      1
# 134                 вой      1
# 135                вода      1
# 136                вино      1
# 137             великое      1
# 138                буря      1
# 139              белена      1
# 140     барыня-сударыня      1
#
# [141 rows x 2 columns]

# %%
df.to_excel('text_output.xls')
